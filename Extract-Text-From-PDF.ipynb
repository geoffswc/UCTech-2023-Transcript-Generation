# %%
#!pip install google-cloud
#!pip install google-cloud-speech
#!pip install google-cloud-storage
#!pip install google-cloud-vision

# %%
import urllib.request
from urllib.request import urlretrieve
from google.cloud import storage
from google.cloud import speech
from google.cloud import vision
from google.cloud import language_v1
import yaml
import json
import os
import re

# %%
def format_url(document_id):
    url = []
    url.append('https://download.industrydocuments.ucsf.edu')
    for i in range(4):
        url.append(document_id[i])
    url.append(document_id)
    url.append(document_id + '.pdf')
    
    return '/'.join(url)

# %%
# download the pdf 
document_id = 'ytxk0091'
download_url = format_url(document_id)
print('downloading', download_url)
urlretrieve(download_url, 'pdfs/' + document_id + ".pdf")
# Out:
# downloading https://download.industrydocuments.ucsf.edu/y/t/x/k/ytxk0091/ytxk0091.pdf
# ('pdfs/ytxk0091.pdf', <http.client.HTTPMessage at 0x7fcae84eaf50>)

# %%
with open('properties.yaml') as file:
    properties = yaml.full_load(file)

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = properties['google_application_credentials']

bucket_name = properties['bucket_name']
storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)

# %%
source_file_name = document_id
blob = bucket.blob(source_file_name)
blob = bucket.blob("pdf_files/" + source_file_name + '.pdf')
blob.upload_from_filename('pdfs/' + source_file_name + '.pdf')

# %%
gcs_source_uri = 'gs://idl-dsi-bucket/pdf_files/' + source_file_name + '.pdf'
gcs_destination_uri = 'gs://idl-dsi-bucket/pdf_files/' + source_file_name + '.json'

# Supported mime_types are: 'application/pdf' and 'image/tiff'
mime_type = "application/pdf"

# How many pages should be grouped into each json output file.
batch_size = 10

client = vision.ImageAnnotatorClient()

feature = vision.Feature(type_=vision.Feature.Type.DOCUMENT_TEXT_DETECTION)

gcs_source = vision.GcsSource(uri=gcs_source_uri)
input_config = vision.InputConfig(gcs_source=gcs_source, mime_type=mime_type)

gcs_destination = vision.GcsDestination(uri=gcs_destination_uri)
output_config = vision.OutputConfig(
    gcs_destination=gcs_destination, batch_size=batch_size
)

async_request = vision.AsyncAnnotateFileRequest(
    features=[feature], input_config=input_config, output_config=output_config
)

operation = client.async_batch_annotate_files(requests=[async_request])

print("Waiting for the operation to finish.")
operation.result(timeout=420)

# Once the request has completed and the output has been
# written to GCS, we can list all the output files.
storage_client = storage.Client()

match = re.match(r"gs://([^/]+)/(.+)", gcs_destination_uri)
bucket_name = match.group(1)
prefix = match.group(2)

bucket = storage_client.get_bucket(bucket_name)

# List objects with the given prefix, filtering out folders.
blob_list = [
    blob
    for blob in list(bucket.list_blobs(prefix=prefix))
    if not blob.name.endswith("/")
]
print("Output files:")
for blob in blob_list:
    print(blob.name)

# Process the first output file from GCS.
# the first response contains
# the first batch_size number pages of the input file.
output = blob_list[0]

json_string = output.download_as_bytes().decode("utf-8")
response = json.loads(json_string)

# The actual response for the first page of the input file.

first_page_response = response["responses"][0]
annotation = first_page_response["fullTextAnnotation"]

# %%
# Here we print the full text from the first page.
# The response contains more information:
# annotation/pages/blocks/paragraphs/words/symbols
# including confidence scores and bounding boxes

print(annotation["text"])
# Out:
# To All Jobacco Cos.
# Oct. 20/999
# I
# In my own handwriting,
# swear people
# are not taking
# responsibility for their own
# actions. No tone forced any
# ong to buy ous that to blame
# childish
# a co
# to smoke or not smoke.
# company for cree shove
# I quit alcohol 24 year
# II was a beer drinkers
# ago
# I shaved sue Lucky Lagers
# for years dost & a devance.
# think not! I also had
# jaundiect hadn't
# solid food for 2.40 3.
# Let us get realt
# tape response blaming
# Yeater
# our
# others - People or Com-
# panies.
# 52279 1744
# Source: https://www.industrydocuments.ucsf.edu/docs/ytxk0091

# %%
response
# Out:
# {'inputConfig': {'gcsSource': {'uri': 'gs://idl-dsi-bucket/pdf_files/ytxk0091.pdf'},
#   'mimeType': 'application/pdf'},
#  'responses': [{'fullTextAnnotation': {'pages': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#          'confidence': 0.95961183}]},
#       'width': 609,
#       'height': 808,
#       'blocks': [{'boundingBox': {'normalizedVertices': [{'x': 0.28735632,
#            'y': 0.22153465},
#           {'x': 0.73399013, 'y': 0.18688118},
#           {'x': 0.7389163, 'y': 0.22277227},
#           {'x': 0.29228243, 'y': 0.25742576}]},
#         'paragraphs': [{'boundingBox': {'normalizedVertices': [{'x': 0.28735632,
#              'y': 0.22153465},
#             {'x': 0.73399013, 'y': 0.18688118},
#             {'x': 0.7389163, 'y': 0.22277227},
#             {'x': 0.29228243, 'y': 0.25742576}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.28735632,
#                'y': 0.22153465},
#               {'x': 0.34154353, 'y': 0.21658416},
#               {'x': 0.3464696, 'y': 0.25371286},
#               {'x': 0.29228243, 'y': 0.25742576}]},
#             'symbols': [{'text': 'T', 'confidence': 0.6733245},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'o',
#               'confidence': 0.8474391}],
#             'confidence': 0.7603818},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.3678161,
#                'y': 0.21534653},
#               {'x': 0.43678162, 'y': 0.21039604},
#               {'x': 0.44170773, 'y': 0.2450495},
#               {'x': 0.3727422, 'y': 0.25123763}]},
#             'symbols': [{'text': 'A', 'confidence': 0.7812596},
#              {'text': 'l', 'confidence': 0.97766614},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'l',
#               'confidence': 0.98278207}],
#             'confidence': 0.9139026},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.44663382,
#                'y': 0.20915842},
#               {'x': 0.6174056, 'y': 0.19554456},
#               {'x': 0.6223317, 'y': 0.23143564},
#               {'x': 0.45155993, 'y': 0.2450495}]},
#             'symbols': [{'text': 'J', 'confidence': 0.51487243},
#              {'text': 'o', 'confidence': 0.9514049},
#              {'text': 'b', 'confidence': 0.9699127},
#              {'text': 'a', 'confidence': 0.95884776},
#              {'text': 'c', 'confidence': 0.9168768},
#              {'text': 'c', 'confidence': 0.60019165},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'o',
#               'confidence': 0.93368226}],
#             'confidence': 0.83511263},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.6403941,
#                'y': 0.19430692},
#               {'x': 0.7126437, 'y': 0.18811882},
#               {'x': 0.71756977, 'y': 0.2240099},
#               {'x': 0.6453202, 'y': 0.23019803}]},
#             'symbols': [{'text': 'C', 'confidence': 0.7655708},
#              {'text': 'o', 'confidence': 0.55339164},
#              {'text': 's', 'confidence': 0.6236206}],
#             'confidence': 0.6475277},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.71756977,
#                'y': 0.18811882},
#               {'x': 0.73399013, 'y': 0.18688118},
#               {'x': 0.7389163, 'y': 0.22277227},
#               {'x': 0.7224959, 'y': 0.2240099}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': '.',
#               'confidence': 0.7766266}],
#             'confidence': 0.7766266}],
#           'confidence': 0.80171686}],
#         'blockType': 'TEXT',
#         'confidence': 0.80171686},
#        {'boundingBox': {'normalizedVertices': [{'x': 0.2857143,
#            'y': 0.26237625},
#           {'x': 0.9507389, 'y': 0.259901},
#           {'x': 0.95238096, 'y': 0.57054454},
#           {'x': 0.28735632, 'y': 0.5730198}]},
#         'paragraphs': [{'boundingBox': {'normalizedVertices': [{'x': 0.70279145,
#              'y': 0.26113862},
#             {'x': 0.9228243, 'y': 0.26485148},
#             {'x': 0.9228243, 'y': 0.2920792},
#             {'x': 0.70279145, 'y': 0.28836635}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.70279145,
#                'y': 0.26113862},
#               {'x': 0.7996716, 'y': 0.26237625},
#               {'x': 0.79802954, 'y': 0.28960395},
#               {'x': 0.70279145, 'y': 0.28836635}]},
#             'symbols': [{'text': 'O', 'confidence': 0.46123037},
#              {'text': 'c', 'confidence': 0.4358325},
#              {'text': 't', 'confidence': 0.6744285},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': '.',
#               'confidence': 0.4147231}],
#             'confidence': 0.49655363},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.8062397,
#                'y': 0.26237625},
#               {'x': 0.9228243, 'y': 0.26485148},
#               {'x': 0.9228243, 'y': 0.2920792},
#               {'x': 0.8062397, 'y': 0.28960395}]},
#             'symbols': [{'text': '2', 'confidence': 0.92488253},
#              {'text': '0', 'confidence': 0.95343417},
#              {'text': '/', 'confidence': 0.5178074},
#              {'text': '9', 'confidence': 0.8742942},
#              {'text': '9', 'confidence': 0.80033827},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': '9',
#               'confidence': 0.9542347}],
#             'confidence': 0.83749855}],
#           'confidence': 0.70112056},
#          {'boundingBox': {'normalizedVertices': [{'x': 0.8965517,
#              'y': 0.32549506},
#             {'x': 0.92610836, 'y': 0.32673267},
#             {'x': 0.9244663, 'y': 0.3539604},
#             {'x': 0.8965517, 'y': 0.35272276}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.8965517,
#                'y': 0.32549506},
#               {'x': 0.92610836, 'y': 0.32673267},
#               {'x': 0.9244663, 'y': 0.3539604},
#               {'x': 0.8965517, 'y': 0.35272276}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': 'I',
#               'confidence': 0.9917481}],
#             'confidence': 0.9917481}],
#           'confidence': 0.9917481},
#          {'boundingBox': {'normalizedVertices': [{'x': 0.2857143,
#              'y': 0.32549506},
#             {'x': 0.9507389, 'y': 0.32178217},
#             {'x': 0.95238096, 'y': 0.49876237},
#             {'x': 0.28735632, 'y': 0.5037129}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.3464696,
#                'y': 0.32549506},
#               {'x': 0.40722495, 'y': 0.32549506},
#               {'x': 0.40722495, 'y': 0.36014852},
#               {'x': 0.3464696, 'y': 0.36138615}]},
#             'symbols': [{'text': 'I', 'confidence': 0.90913326},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'n',
#               'confidence': 0.9212896}],
#             'confidence': 0.91521144},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.4318555,
#                'y': 0.32549506},
#               {'x': 0.51724136, 'y': 0.32549506},
#               {'x': 0.51724136, 'y': 0.36014852},
#               {'x': 0.4318555, 'y': 0.36014852}]},
#             'symbols': [{'text': 'm', 'confidence': 0.84291255},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'y',
#               'confidence': 0.98384285}],
#             'confidence': 0.9133777},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.52545154,
#                'y': 0.32425743},
#               {'x': 0.61083746, 'y': 0.32425743},
#               {'x': 0.61247945, 'y': 0.3589109},
#               {'x': 0.5270936, 'y': 0.36014852}]},
#             'symbols': [{'text': 'o', 'confidence': 0.98062134},
#              {'text': 'w', 'confidence': 0.98726255},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'n',
#               'confidence': 0.9919442}],
#             'confidence': 0.98660934},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.63875204,
#                'y': 0.32425743},
#               {'x': 0.88834155, 'y': 0.32178217},
#               {'x': 0.88834155, 'y': 0.35767326},
#               {'x': 0.63875204, 'y': 0.3589109}]},
#             'symbols': [{'text': 'h', 'confidence': 0.8101893},
#              {'text': 'a', 'confidence': 0.5597982},
#              {'text': 'n', 'confidence': 0.6428186},
#              {'text': 'd', 'confidence': 0.8473129},
#              {'text': 'w', 'confidence': 0.9079282},
#              {'text': 'r', 'confidence': 0.9572194},
#              {'text': 'i', 'confidence': 0.9884334},
#              {'text': 't', 'confidence': 0.9915457},
#              {'text': 'i', 'confidence': 0.9935084},
#              {'text': 'n', 'confidence': 0.96926713},
#              {'text': 'g', 'confidence': 0.9566743}],
#             'confidence': 0.87497234},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.87027913,
#                'y': 0.32178217},
#               {'x': 0.90311986, 'y': 0.32178217},
#               {'x': 0.9047619, 'y': 0.35643566},
#               {'x': 0.87027913, 'y': 0.35643566}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'text': ',',
#               'confidence': 0.61082786}],
#             'confidence': 0.61082786},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.2857143,
#                'y': 0.36633664},
#               {'x': 0.42036125, 'y': 0.36262375},
#               {'x': 0.42200327, 'y': 0.39356434},
#               {'x': 0.28735632, 'y': 0.39727724}]},
#             'symbols': [{'text': 's', 'confidence': 0.8236187},
#              {'text': 'w', 'confidence': 0.6904864},
#              {'text': 'e', 'confidence': 0.93555945},
#              {'text': 'a', 'confidence': 0.90269536},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'r',
#               'confidence': 0.8336206}],
#             'confidence': 0.8371961},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.43842363,
#                'y': 0.36138615},
#               {'x': 0.57471263, 'y': 0.35767326},
#               {'x': 0.5763547, 'y': 0.38861385},
#               {'x': 0.44006568, 'y': 0.39232674}]},
#             'symbols': [{'text': 'p', 'confidence': 0.9024377},
#              {'text': 'e', 'confidence': 0.7383821},
#              {'text': 'o', 'confidence': 0.95404494},
#              {'text': 'p', 'confidence': 0.88754493},
#              {'text': 'l', 'confidence': 0.9903037},
#              {'property': {'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'text': 'e',
#               'confidence': 0.9899649}],
#             'confidence': 0.9104464},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.58949095,
#                'y': 0.35643566},
#               {'x': 0.66174054, 'y': 0.35643566},
#               {'x': 0.6600985, 'y': 0.3910891},
#               {'x': 0.58949095, 'y': 0.38985148}]},
#             'symbols': [{'text': 'a', 'confidence': 0.99154395},
#              {'text': 'r', 'confidence': 0.99316835},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'e',
#               'confidence': 0.99541426}],
#             'confidence': 0.99337554},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.68801314,
#                'y': 0.35643566},
#               {'x': 0.773399, 'y': 0.35767326},
#               {'x': 0.773399, 'y': 0.3910891},
#               {'x': 0.68801314, 'y': 0.3910891}]},
#             'symbols': [{'text': 'n', 'confidence': 0.9847683},
#              {'text': 'o', 'confidence': 0.9907092},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 't',
#               'confidence': 0.9879402}],
#             'confidence': 0.9878059},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.7832512,
#                'y': 0.35767326},
#               {'x': 0.9228243, 'y': 0.35767326},
#               {'x': 0.9211823, 'y': 0.39232674},
#               {'x': 0.7832512, 'y': 0.3910891}]},
#             'symbols': [{'text': 't', 'confidence': 0.8520497},
#              {'text': 'a', 'confidence': 0.93726605},
#              {'text': 'k', 'confidence': 0.9347949},
#              {'text': 'i', 'confidence': 0.9841243},
#              {'text': 'n', 'confidence': 0.98614836},
#              {'property': {'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'text': 'g',
#               'confidence': 0.9816218}],
#             'confidence': 0.9460009},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.29885057,
#                'y': 0.3910891},
#               {'x': 0.591133, 'y': 0.38737625},
#               {'x': 0.59277505, 'y': 0.4220297},
#               {'x': 0.3004926, 'y': 0.42574257}]},
#             'symbols': [{'text': 'r', 'confidence': 0.710629},
#              {'text': 'e', 'confidence': 0.84105295},
#              {'text': 's', 'confidence': 0.72776765},
#              {'text': 'p', 'confidence': 0.9220334},
#              {'text': 'o', 'confidence': 0.6550847},
#              {'text': 'n', 'confidence': 0.5112497},
#              {'text': 's', 'confidence': 0.47462276},
#              {'text': 'i', 'confidence': 0.5819866},
#              {'text': 'b', 'confidence': 0.51852274},
#              {'text': 'i', 'confidence': 0.32803538},
#              {'text': 'l', 'confidence': 0.46816856},
#              {'text': 'i', 'confidence': 0.7334105},
#              {'text': 't', 'confidence': 0.92466897},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'y',
#               'confidence': 0.96728355}],
#             'confidence': 0.66889405},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.6059113,
#                'y': 0.38613862},
#               {'x': 0.67651886, 'y': 0.384901},
#               {'x': 0.6781609, 'y': 0.41955444},
#               {'x': 0.60755336, 'y': 0.4220297}]},
#             'symbols': [{'text': 'f', 'confidence': 0.9831392},
#              {'text': 'o', 'confidence': 0.98394364},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'r',
#               'confidence': 0.96911514}],
#             'confidence': 0.97873265},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.6863711,
#                'y': 0.38613862},
#               {'x': 0.7947455, 'y': 0.38366336},
#               {'x': 0.7963875, 'y': 0.41831684},
#               {'x': 0.68801314, 'y': 0.41955444}]},
#             'symbols': [{'text': 't', 'confidence': 0.9810829},
#              {'text': 'h', 'confidence': 0.99365824},
#              {'text': 'e', 'confidence': 0.9966145},
#              {'text': 'i', 'confidence': 0.9886494},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'r',
#               'confidence': 0.99209833}],
#             'confidence': 0.9904207},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.81609195,
#                'y': 0.38366336},
#               {'x': 0.9244663, 'y': 0.38242576},
#               {'x': 0.92610836, 'y': 0.4170792},
#               {'x': 0.817734, 'y': 0.41831684}]},
#             'symbols': [{'text': 'o', 'confidence': 0.94158643},
#              {'text': 'w', 'confidence': 0.90449566},
#              {'property': {'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'text': 'n',
#               'confidence': 0.9440595}],
#             'confidence': 0.9300472},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.30541873,
#                'y': 0.41336635},
#               {'x': 0.4729064, 'y': 0.41460395},
#               {'x': 0.4729064, 'y': 0.45915842},
#               {'x': 0.30541873, 'y': 0.4579208}]},
#             'symbols': [{'text': 'a', 'confidence': 0.98201025},
#              {'text': 'c', 'confidence': 0.98216945},
#              {'text': 't', 'confidence': 0.9823566},
#              {'text': 'i', 'confidence': 0.98498267},
#              {'text': 'o', 'confidence': 0.9811986},
#              {'text': 'n', 'confidence': 0.94165903},
#              {'text': 's', 'confidence': 0.6211643}],
#             'confidence': 0.92507726},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.45648605,
#                'y': 0.41460395},
#               {'x': 0.48604268, 'y': 0.41460395},
#               {'x': 0.48604268, 'y': 0.45915842},
#               {'x': 0.45648605, 'y': 0.45915842}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': '.',
#               'confidence': 0.4797371}],
#             'confidence': 0.4797371},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.49917898,
#                'y': 0.41460395},
#               {'x': 0.5648604, 'y': 0.41584158},
#               {'x': 0.5632184, 'y': 0.45915842},
#               {'x': 0.49753696, 'y': 0.45915842}]},
#             'symbols': [{'text': 'N', 'confidence': 0.5350597},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'o',
#               'confidence': 0.94664353}],
#             'confidence': 0.74085164},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5599343,
#                'y': 0.41584158},
#               {'x': 0.6551724, 'y': 0.41584158},
#               {'x': 0.6551724, 'y': 0.46039605},
#               {'x': 0.55829227, 'y': 0.46039605}]},
#             'symbols': [{'text': 't', 'confidence': 0.5472618},
#              {'text': 'o', 'confidence': 0.40963623},
#              {'text': 'n', 'confidence': 0.6471931},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'e',
#               'confidence': 0.8386458}],
#             'confidence': 0.6106842},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.68308705,
#                'y': 0.41584158},
#               {'x': 0.8374384, 'y': 0.4170792},
#               {'x': 0.8357964, 'y': 0.46287128},
#               {'x': 0.68308705, 'y': 0.46039605}]},
#             'symbols': [{'text': 'f', 'confidence': 0.8139973},
#              {'text': 'o', 'confidence': 0.85369414},
#              {'text': 'r', 'confidence': 0.473179},
#              {'text': 'c', 'confidence': 0.45050678},
#              {'text': 'e', 'confidence': 0.8705365},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'd',
#               'confidence': 0.93553853}],
#             'confidence': 0.7329087},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.8604269,
#                'y': 0.41831684},
#               {'x': 0.9425287, 'y': 0.41831684},
#               {'x': 0.9425287, 'y': 0.46287128},
#               {'x': 0.8587849, 'y': 0.46287128}]},
#             'symbols': [{'text': 'a', 'confidence': 0.85785276},
#              {'text': 'n', 'confidence': 0.9656},
#              {'property': {'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'text': 'y',
#               'confidence': 0.96693206}],
#             'confidence': 0.9301283},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.30541873,
#                'y': 0.45915842},
#               {'x': 0.3908046, 'y': 0.45915842},
#               {'x': 0.3908046, 'y': 0.49876237},
#               {'x': 0.30541873, 'y': 0.49876237}]},
#             'symbols': [{'text': 'o', 'confidence': 0.82486},
#              {'text': 'n', 'confidence': 0.7980562},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'g',
#               'confidence': 0.5204017}],
#             'confidence': 0.7144393},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.39244664,
#                'y': 0.45915842},
#               {'x': 0.44006568, 'y': 0.45915842},
#               {'x': 0.44006568, 'y': 0.49876237},
#               {'x': 0.39244664, 'y': 0.49876237}]},
#             'symbols': [{'text': 't', 'confidence': 0.988161},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'o',
#               'confidence': 0.9937103}],
#             'confidence': 0.9909357},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.44827586,
#                'y': 0.45915842},
#               {'x': 0.54679805, 'y': 0.45915842},
#               {'x': 0.54679805, 'y': 0.49876237},
#               {'x': 0.44827586, 'y': 0.49876237}]},
#             'symbols': [{'text': 'b', 'confidence': 0.9326902},
#              {'text': 'u', 'confidence': 0.66141266},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'y',
#               'confidence': 0.92019385}],
#             'confidence': 0.8380989},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.55500823,
#                'y': 0.45915842},
#               {'x': 0.6551724, 'y': 0.45915842},
#               {'x': 0.6551724, 'y': 0.49876237},
#               {'x': 0.55500823, 'y': 0.49876237}]},
#             'symbols': [{'text': 'o', 'confidence': 0.6090472},
#              {'text': 'u', 'confidence': 0.35767666},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 's',
#               'confidence': 0.32906964}],
#             'confidence': 0.43193117},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.65353036,
#                'y': 0.45915842},
#               {'x': 0.75205255, 'y': 0.45915842},
#               {'x': 0.75205255, 'y': 0.49876237},
#               {'x': 0.65353036, 'y': 0.49876237}]},
#             'symbols': [{'text': 't', 'confidence': 0.59634745},
#              {'text': 'h', 'confidence': 0.47935662},
#              {'text': 'a', 'confidence': 0.2955986},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 't',
#               'confidence': 0.47154835}],
#             'confidence': 0.46071276},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.773399,
#                'y': 0.45915842},
#               {'x': 0.82430214, 'y': 0.45915842},
#               {'x': 0.82430214, 'y': 0.49876237},
#               {'x': 0.773399, 'y': 0.49876237}]},
#             'symbols': [{'text': 't', 'confidence': 0.94582105},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'o',
#               'confidence': 0.9384321}],
#             'confidence': 0.9421266},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.82101804,
#                'y': 0.45915842},
#               {'x': 0.95238096, 'y': 0.45915842},
#               {'x': 0.95238096, 'y': 0.49876237},
#               {'x': 0.82101804, 'y': 0.49876237}]},
#             'symbols': [{'text': 'b', 'confidence': 0.84576964},
#              {'text': 'l', 'confidence': 0.70338607},
#              {'text': 'a', 'confidence': 0.5860996},
#              {'text': 'm', 'confidence': 0.8551544},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': 'e',
#               'confidence': 0.8903407}],
#             'confidence': 0.7761501}],
#           'confidence': 0.8178973},
#          {'boundingBox': {'normalizedVertices': [{'x': 0.5533662,
#              'y': 0.48143566},
#             {'x': 0.74876845, 'y': 0.47772276},
#             {'x': 0.74876845, 'y': 0.5037129},
#             {'x': 0.5533662, 'y': 0.5061881}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5533662,
#                'y': 0.48143566},
#               {'x': 0.74876845, 'y': 0.47772276},
#               {'x': 0.74876845, 'y': 0.5037129},
#               {'x': 0.5533662, 'y': 0.5061881}]},
#             'symbols': [{'text': 'c', 'confidence': 0.406409},
#              {'text': 'h', 'confidence': 0.87557465},
#              {'text': 'i', 'confidence': 0.91267765},
#              {'text': 'l', 'confidence': 0.98312116},
#              {'text': 'd', 'confidence': 0.97761565},
#              {'text': 'i', 'confidence': 0.9688565},
#              {'text': 's', 'confidence': 0.97897124},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': 'h',
#               'confidence': 0.9910666}],
#             'confidence': 0.8867866}],
#           'confidence': 0.8867866},
#          {'boundingBox': {'normalizedVertices': [{'x': 0.30213463,
#              'y': 0.519802},
#             {'x': 0.40065682, 'y': 0.51856434},
#             {'x': 0.40065682, 'y': 0.5321782},
#             {'x': 0.30213463, 'y': 0.53341585}]},
#           'words': [{'boundingBox': {'normalizedVertices': [{'x': 0.30213463,
#                'y': 0.519802},
#               {'x': 0.33497536, 'y': 0.519802},
#               {'x': 0.33497536, 'y': 0.5321782},
#               {'x': 0.30213463, 'y': 0.53341585}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'a',
#               'confidence': 0.9623352}],
#             'confidence': 0.9623352},
#            {'boundingBox': {'normalizedVertices': [{'x': 0.35632184,
#                'y': 0.51856434},
#               {'x': 0.40065682, 'y': 0.51856434},
#               {'x': 0.40065682, 'y': 0.5321782},
#               {'x': 0.35632184, 'y': 0.5321782}]},
#             'symbols': [{'text': 'c', 'confidence': 0.8630611},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': 'o',
#               'confidence': 0.9018407}],
#             'confidence': 0.8824509}],
#           'confidence': 0.909079},
#          {'boundingBox': {'normalizedVertices': [{'x': 0.30377668,
#              'y': 0.5408416},
#             {'x': 0.8949097, 'y': 0.5445545},
#             {'x': 0.8949097, 'y': 0.57054454},
#             {'x': 0.30377668, 'y': 0.5668317}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.30377668,
#                'y': 0.5420792},
#               {'x': 0.3448276, 'y': 0.5420792},
#               {'x': 0.3448276, 'y': 0.5680693},
#               {'x': 0.30377668, 'y': 0.5668317}]},
#             'symbols': [{'text': 't', 'confidence': 0.9844132},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'o',
#               'confidence': 0.9908982}],
#             'confidence': 0.9876557},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.3579639,
#                'y': 0.5420792},
#               {'x': 0.5139573, 'y': 0.5420792},
#               {'x': 0.5139573, 'y': 0.5680693},
#               {'x': 0.3579639, 'y': 0.5680693}]},
#             'symbols': [{'text': 's', 'confidence': 0.9887683},
#              {'text': 'm', 'confidence': 0.9788376},
#              {'text': 'o', 'confidence': 0.92296785},
#              {'text': 'k', 'confidence': 0.8458879},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'e',
#               'confidence': 0.9734989}],
#             'confidence': 0.9419921},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.52380955,
#                'y': 0.54331684},
#               {'x': 0.57799673, 'y': 0.54331684},
#               {'x': 0.57799673, 'y': 0.5693069},
#               {'x': 0.52380955, 'y': 0.5680693}]},
#             'symbols': [{'text': 'o', 'confidence': 0.6984282},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'r',
#               'confidence': 0.3910238}],
#             'confidence': 0.544726},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.60426927,
#                'y': 0.54331684},
#               {'x': 0.6896552, 'y': 0.54331684},
#               {'x': 0.6896552, 'y': 0.5693069},
#               {'x': 0.60426927, 'y': 0.5693069}]},
#             'symbols': [{'text': 'n', 'confidence': 0.9741372},
#              {'text': 'o', 'confidence': 0.9709929},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 't',
#               'confidence': 0.98486763}],
#             'confidence': 0.9766659},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.6995074,
#                'y': 0.54331684},
#               {'x': 0.8555008, 'y': 0.5445545},
#               {'x': 0.8555008, 'y': 0.57054454},
#               {'x': 0.6995074, 'y': 0.57054454}]},
#             'symbols': [{'text': 's', 'confidence': 0.9762212},
#              {'text': 'm', 'confidence': 0.9251192},
#              {'text': 'o', 'confidence': 0.94261706},
#              {'text': 'k', 'confidence': 0.7974242},
#              {'text': 'e', 'confidence': 0.94070596}],
#             'confidence': 0.91641754},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.8555008,
#                'y': 0.5445545},
#               {'x': 0.8949097, 'y': 0.5457921},
#               {'x': 0.8949097, 'y': 0.57054454},
#               {'x': 0.8555008, 'y': 0.57054454}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': '.',
#               'confidence': 0.55646926}],
#             'confidence': 0.55646926}],
#           'confidence': 0.88018215},
#          {'boundingBox': {'normalizedVertices': [{'x': 0.35303777,
#              'y': 0.52227724},
#             {'x': 0.9408867, 'y': 0.4950495},
#             {'x': 0.9441708, 'y': 0.5358911},
#             {'x': 0.35632184, 'y': 0.5631188}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.35303777,
#                'y': 0.52227724},
#               {'x': 0.5829228, 'y': 0.5111386},
#               {'x': 0.5862069, 'y': 0.5519802},
#               {'x': 0.35632184, 'y': 0.5631188}]},
#             'symbols': [{'text': 'c', 'confidence': 0.980504},
#              {'text': 'o', 'confidence': 0.9802572},
#              {'text': 'm', 'confidence': 0.9917385},
#              {'text': 'p', 'confidence': 0.9870056},
#              {'text': 'a', 'confidence': 0.9897053},
#              {'text': 'n', 'confidence': 0.990973},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'y',
#               'confidence': 0.99511033}],
#             'confidence': 0.9878991},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5993432,
#                'y': 0.5111386},
#               {'x': 0.681445, 'y': 0.5074257},
#               {'x': 0.68308705, 'y': 0.5470297},
#               {'x': 0.6026273, 'y': 0.55074257}]},
#             'symbols': [{'text': 'f', 'confidence': 0.9887937},
#              {'text': 'o', 'confidence': 0.9945413},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'r',
#               'confidence': 0.9903532}],
#             'confidence': 0.9912294},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.6962233,
#                'y': 0.5061881},
#               {'x': 0.8029557, 'y': 0.50123763},
#               {'x': 0.8062397, 'y': 0.5420792},
#               {'x': 0.6995074, 'y': 0.5470297}]},
#             'symbols': [{'text': 'c', 'confidence': 0.7994784},
#              {'text': 'r', 'confidence': 0.6900915},
#              {'text': 'e', 'confidence': 0.9068075},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'e',
#               'confidence': 0.60184264}],
#             'confidence': 0.749555},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.81937605,
#                'y': 0.50123763},
#               {'x': 0.9408867, 'y': 0.4950495},
#               {'x': 0.9441708, 'y': 0.5358911},
#               {'x': 0.82430214, 'y': 0.5408416}]},
#             'symbols': [{'text': 's', 'confidence': 0.85850745},
#              {'text': 'h', 'confidence': 0.8931051},
#              {'text': 'o', 'confidence': 0.7769851},
#              {'text': 'v', 'confidence': 0.326987},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': 'e',
#               'confidence': 0.87540114}],
#             'confidence': 0.74619716}],
#           'confidence': 0.8746415}],
#         'blockType': 'TEXT',
#         'confidence': 0.8307622},
#        {'boundingBox': {'normalizedVertices': [{'x': 0.28078818,
#            'y': 0.57425743},
#           {'x': 0.94745487, 'y': 0.5594059},
#           {'x': 0.9622332, 'y': 0.9022277},
#           {'x': 0.29392448, 'y': 0.9170792}]},
#         'paragraphs': [{'boundingBox': {'normalizedVertices': [{'x': 0.29392448,
#              'y': 0.57425743},
#             {'x': 0.94909686, 'y': 0.57549506},
#             {'x': 0.94909686, 'y': 0.9022277},
#             {'x': 0.29392448, 'y': 0.9022277}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.3546798,
#                'y': 0.57425743},
#               {'x': 0.40722495, 'y': 0.57549506},
#               {'x': 0.40722495, 'y': 0.61262375},
#               {'x': 0.3546798, 'y': 0.6113861}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'I',
#               'confidence': 0.9508185}],
#             'confidence': 0.9508185},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.41379312,
#                'y': 0.57425743},
#               {'x': 0.5320197, 'y': 0.57549506},
#               {'x': 0.5303777, 'y': 0.6138614},
#               {'x': 0.41379312, 'y': 0.61262375}]},
#             'symbols': [{'text': 'q', 'confidence': 0.56998},
#              {'text': 'u', 'confidence': 0.9324428},
#              {'text': 'i', 'confidence': 0.6553798},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 't',
#               'confidence': 0.9674803}],
#             'confidence': 0.7813207},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5418719,
#                'y': 0.57549506},
#               {'x': 0.7241379, 'y': 0.5779703},
#               {'x': 0.7224959, 'y': 0.615099},
#               {'x': 0.54022986, 'y': 0.6138614}]},
#             'symbols': [{'text': 'a', 'confidence': 0.9274453},
#              {'text': 'l', 'confidence': 0.65838027},
#              {'text': 'c', 'confidence': 0.40752319},
#              {'text': 'o', 'confidence': 0.31644934},
#              {'text': 'h', 'confidence': 0.6863434},
#              {'text': 'o', 'confidence': 0.67161256},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'l',
#               'confidence': 0.84427345}],
#             'confidence': 0.64457536},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.74055827,
#                'y': 0.5779703},
#               {'x': 0.817734, 'y': 0.5792079},
#               {'x': 0.817734, 'y': 0.61633664},
#               {'x': 0.74055827, 'y': 0.615099}]},
#             'symbols': [{'text': '2', 'confidence': 0.97265697},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': '4',
#               'confidence': 0.9096573}],
#             'confidence': 0.9411571},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.8144499,
#                'y': 0.5792079},
#               {'x': 0.93760264, 'y': 0.5804455},
#               {'x': 0.93760264, 'y': 0.6175743},
#               {'x': 0.8144499, 'y': 0.61633664}]},
#             'symbols': [{'text': 'y', 'confidence': 0.90600294},
#              {'text': 'e', 'confidence': 0.763882},
#              {'text': 'a', 'confidence': 0.94831914},
#              {'property': {'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'text': 'r',
#               'confidence': 0.8003314}],
#             'confidence': 0.85463387},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.408867,
#                'y': 0.59653467},
#               {'x': 0.47947454, 'y': 0.5977723},
#               {'x': 0.47947454, 'y': 0.63366336},
#               {'x': 0.40722495, 'y': 0.6324257}]},
#             'symbols': [{'text': 'I', 'confidence': 0.8729911},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'I',
#               'confidence': 0.6045331}],
#             'confidence': 0.7387621},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.48768473,
#                'y': 0.5977723},
#               {'x': 0.57471263, 'y': 0.5990099},
#               {'x': 0.5730706, 'y': 0.634901},
#               {'x': 0.48604268, 'y': 0.63366336}]},
#             'symbols': [{'text': 'w', 'confidence': 0.99082667},
#              {'text': 'a', 'confidence': 0.99271786},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 's',
#               'confidence': 0.99227154}],
#             'confidence': 0.9919387},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.59277505,
#                'y': 0.6002475},
#               {'x': 0.6272578, 'y': 0.6002475},
#               {'x': 0.6256158, 'y': 0.634901},
#               {'x': 0.591133, 'y': 0.634901}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'a',
#               'confidence': 0.9870802}],
#             'confidence': 0.9870802},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.6403941,
#                'y': 0.6002475},
#               {'x': 0.7372742, 'y': 0.60272276},
#               {'x': 0.7372742, 'y': 0.63737625},
#               {'x': 0.6403941, 'y': 0.6361386}]},
#             'symbols': [{'text': 'b', 'confidence': 0.83326447},
#              {'text': 'e', 'confidence': 0.34133592},
#              {'text': 'e', 'confidence': 0.47972143},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'r',
#               'confidence': 0.6235852}],
#             'confidence': 0.5694768},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.75697863,
#                'y': 0.60272276},
#               {'x': 0.9408867, 'y': 0.605198},
#               {'x': 0.9392447, 'y': 0.6410891},
#               {'x': 0.75533664, 'y': 0.6386139}]},
#             'symbols': [{'text': 'd', 'confidence': 0.7700592},
#              {'text': 'r', 'confidence': 0.37783355},
#              {'text': 'i', 'confidence': 0.30648628},
#              {'text': 'n', 'confidence': 0.2941697},
#              {'text': 'k', 'confidence': 0.28073975},
#              {'text': 'e', 'confidence': 0.42219013},
#              {'text': 'r', 'confidence': 0.39339578},
#              {'property': {'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'text': 's',
#               'confidence': 0.41430894}],
#             'confidence': 0.40739793},
#            {'boundingBox': {'normalizedVertices': [{'x': 0.29392448,
#                'y': 0.6188119},
#               {'x': 0.3825944, 'y': 0.61633664},
#               {'x': 0.38423645, 'y': 0.6571782},
#               {'x': 0.2955665, 'y': 0.6596535}]},
#             'symbols': [{'text': 'a', 'confidence': 0.967727},
#              {'text': 'g', 'confidence': 0.9691206},
#              {'property': {'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'text': 'o',
#               'confidence': 0.4554942}],
#             'confidence': 0.79744726},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.31527093,
#                'y': 0.6299505},
#               {'x': 0.36453202, 'y': 0.6311881},
#               {'x': 0.36453202, 'y': 0.6695545},
#               {'x': 0.3136289, 'y': 0.6695545}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'I',
#               'confidence': 0.9928554}],
#             'confidence': 0.9928554},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.3727422,
#                'y': 0.6299505},
#               {'x': 0.54022986, 'y': 0.6324257},
#               {'x': 0.53858787, 'y': 0.6720297},
#               {'x': 0.37110016, 'y': 0.6695545}]},
#             'symbols': [{'text': 's', 'confidence': 0.9684848},
#              {'text': 'h', 'confidence': 0.9499802},
#              {'text': 'a', 'confidence': 0.58837664},
#              {'text': 'v', 'confidence': 0.7065354},
#              {'text': 'e', 'confidence': 0.7018584},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'd',
#               'confidence': 0.94737035}],
#             'confidence': 0.8104343},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.53858787,
#                'y': 0.6324257},
#               {'x': 0.64203614, 'y': 0.6324257},
#               {'x': 0.64203614, 'y': 0.6720297},
#               {'x': 0.5369458, 'y': 0.6720297}]},
#             'symbols': [{'text': 's', 'confidence': 0.6585821},
#              {'text': 'u', 'confidence': 0.80297387},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'e',
#               'confidence': 0.9593983}],
#             'confidence': 0.8069848},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.66174054,
#                'y': 0.63366336},
#               {'x': 0.81116587, 'y': 0.634901},
#               {'x': 0.81116587, 'y': 0.67450494},
#               {'x': 0.6600985, 'y': 0.6732673}]},
#             'symbols': [{'text': 'L', 'confidence': 0.8170447},
#              {'text': 'u', 'confidence': 0.69004583},
#              {'text': 'c', 'confidence': 0.67608887},
#              {'text': 'k', 'confidence': 0.8053948},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'y',
#               'confidence': 0.84469295}],
#             'confidence': 0.7666534},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.81609195,
#                'y': 0.634901},
#               {'x': 0.94909686, 'y': 0.6361386},
#               {'x': 0.94909686, 'y': 0.67574257},
#               {'x': 0.81609195, 'y': 0.67450494}]},
#             'symbols': [{'text': 'L', 'confidence': 0.9286366},
#              {'text': 'a', 'confidence': 0.940365},
#              {'text': 'g', 'confidence': 0.825899},
#              {'text': 'e', 'confidence': 0.8514988},
#              {'text': 'r', 'confidence': 0.41619492},
#              {'property': {'detectedBreak': {'type': 'EOL_SURE_SPACE'}},
#               'text': 's',
#               'confidence': 0.46000388}],
#             'confidence': 0.7370997},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.30213463,
#                'y': 0.6769802},
#               {'x': 0.3809524, 'y': 0.67450494},
#               {'x': 0.3825944, 'y': 0.7079208},
#               {'x': 0.30377668, 'y': 0.71039605}]},
#             'symbols': [{'text': 'f', 'confidence': 0.97938615},
#              {'text': 'o', 'confidence': 0.9827838},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'r',
#               'confidence': 0.9933741}],
#             'confidence': 0.98518133},
# ...
#               {'x': 0.93935794, 'y': 0.27760252},
#               {'x': 0.843044, 'y': 0.2807571}]},
#             'symbols': [{'text': 'T', 'confidence': 0.9336763},
#              {'text': 'o', 'confidence': 0.854379},
#              {'text': 'b', 'confidence': 0.95374244},
#              {'text': 'a', 'confidence': 0.66104615},
#              {'text': 'c', 'confidence': 0.73986167},
#              {'text': 'c', 'confidence': 0.7433258},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': 'o',
#               'confidence': 0.87100613}],
#             'confidence': 0.82243395}],
#           'confidence': 0.86665386},
#          {'boundingBox': {'normalizedVertices': [{'x': 0.8941736,
#              'y': 0.26971608},
#             {'x': 0.92865634, 'y': 0.27129337},
#             {'x': 0.92865634, 'y': 0.28864354},
#             {'x': 0.8941736, 'y': 0.28548896}]},
#           'words': [{'boundingBox': {'normalizedVertices': [{'x': 0.8941736,
#                'y': 0.26971608},
#               {'x': 0.92865634, 'y': 0.27129337},
#               {'x': 0.92865634, 'y': 0.28864354},
#               {'x': 0.8941736, 'y': 0.28548896}]},
#             'symbols': [{'text': 'C', 'confidence': 0.41299915},
#              {'text': 'o', 'confidence': 0.4517481},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': '.',
#               'confidence': 0.5180218}],
#             'confidence': 0.46092302}],
#           'confidence': 0.46092302},
#          {'boundingBox': {'normalizedVertices': [{'x': 0.5802616,
#              'y': 0.2933754},
#             {'x': 0.7146254, 'y': 0.28864354},
#             {'x': 0.71581453, 'y': 0.3154574},
#             {'x': 0.5802616, 'y': 0.32018927}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5802616,
#                'y': 0.2933754},
#               {'x': 0.7146254, 'y': 0.28864354},
#               {'x': 0.71581453, 'y': 0.3154574},
#               {'x': 0.5802616, 'y': 0.32018927}]},
#             'symbols': [{'text': 'W', 'confidence': 0.8850287},
#              {'text': 'I', 'confidence': 0.7419087},
#              {'text': 'N', 'confidence': 0.80194515},
#              {'text': 'S', 'confidence': 0.6107213},
#              {'text': 'T', 'confidence': 0.7723789},
#              {'text': 'O', 'confidence': 0.78457195},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': 'N',
#               'confidence': 0.91469}],
#             'confidence': 0.7873207}],
#           'confidence': 0.7873207},
#          {'boundingBox': {'normalizedVertices': [{'x': 0.74554104,
#              'y': 0.28706625},
#             {'x': 0.84423304, 'y': 0.28706625},
#             {'x': 0.84423304, 'y': 0.31230283},
#             {'x': 0.74554104, 'y': 0.31230283}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.74554104,
#                'y': 0.28706625},
#               {'x': 0.84423304, 'y': 0.28706625},
#               {'x': 0.84423304, 'y': 0.31230283},
#               {'x': 0.74554104, 'y': 0.31230283}]},
#             'symbols': [{'text': 'S', 'confidence': 0.6186125},
#              {'text': 'a', 'confidence': 0.54842955},
#              {'text': 'l', 'confidence': 0.82649726},
#              {'text': 'e', 'confidence': 0.9425849},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': 'm',
#               'confidence': 0.94276196}],
#             'confidence': 0.7757772}],
#           'confidence': 0.7757772}],
#         'blockType': 'TEXT',
#         'confidence': 0.8011566},
#        {'boundingBox': {'normalizedVertices': [{'x': 0.6848989,
#            'y': 0.34542587},
#           {'x': 0.8906064, 'y': 0.34858045},
#           {'x': 0.88941735, 'y': 0.3769716},
#           {'x': 0.68370986, 'y': 0.37381703}]},
#         'paragraphs': [{'boundingBox': {'normalizedVertices': [{'x': 0.6848989,
#              'y': 0.34542587},
#             {'x': 0.8906064, 'y': 0.34858045},
#             {'x': 0.88941735, 'y': 0.3769716},
#             {'x': 0.68370986, 'y': 0.37381703}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.6848989,
#                'y': 0.34542587},
#               {'x': 0.7467301, 'y': 0.34700316},
#               {'x': 0.7467301, 'y': 0.3753943},
#               {'x': 0.68370986, 'y': 0.37381703}]},
#             'symbols': [{'text': 'N', 'confidence': 0.7555222},
#              {'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': 'C',
#               'confidence': 0.6087934}],
#             'confidence': 0.68215775},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.78002375,
#                'y': 0.34700316},
#               {'x': 0.8906064, 'y': 0.34858045},
#               {'x': 0.88941735, 'y': 0.3769716},
#               {'x': 0.78002375, 'y': 0.3753943}]},
#             'symbols': [{'text': '2', 'confidence': 0.9713591},
#              {'text': '7', 'confidence': 0.95634156},
#              {'text': '/', 'confidence': 0.5745782},
#              {'text': '0', 'confidence': 0.87253785},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': '2',
#               'confidence': 0.81379557}],
#             'confidence': 0.8377225}],
#           'confidence': 0.7932754}],
#         'blockType': 'TEXT',
#         'confidence': 0.7932754},
#        {'boundingBox': {'normalizedVertices': [{'x': 0.51486325,
#            'y': 0.4369085},
#           {'x': 0.8263971, 'y': 0.44164038},
#           {'x': 0.8263971, 'y': 0.46056783},
#           {'x': 0.51486325, 'y': 0.45425868}]},
#         'paragraphs': [{'boundingBox': {'normalizedVertices': [{'x': 0.51486325,
#              'y': 0.4369085},
#             {'x': 0.8263971, 'y': 0.44164038},
#             {'x': 0.8263971, 'y': 0.46056783},
#             {'x': 0.51486325, 'y': 0.45425868}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'tr',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.51486325,
#                'y': 0.4369085},
#               {'x': 0.5612366, 'y': 0.4369085},
#               {'x': 0.5612366, 'y': 0.45583597},
#               {'x': 0.51486325, 'y': 0.45425868}]},
#             'symbols': [{'text': 'R', 'confidence': 0.28692853},
#              {'text': 'e', 'confidence': 0.31483865},
#              {'text': 's', 'confidence': 0.35853985},
#              {'text': 's', 'confidence': 0.4433782}],
#             'confidence': 0.3509213},
#            {'property': {'detectedLanguages': [{'languageCode': 'tr',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5612366,
#                'y': 0.4369085},
#               {'x': 0.5648038, 'y': 0.4369085},
#               {'x': 0.5648038, 'y': 0.45583597},
#               {'x': 0.5612366, 'y': 0.45583597}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': ',',
#               'confidence': 0.52687776}],
#             'confidence': 0.52687776},
#            {'property': {'detectedLanguages': [{'languageCode': 'tr',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.5731272,
#                'y': 0.4369085},
#               {'x': 0.8263971, 'y': 0.44164038},
#               {'x': 0.8263971, 'y': 0.46056783},
#               {'x': 0.5731272, 'y': 0.45583597}]},
#             'symbols': [{'text': 'l', 'confidence': 0.3547483},
#              {'text': 'a', 'confidence': 0.32115006},
#              {'text': 'h', 'confidence': 0.33037904},
#              {'text': 'ı', 'confidence': 0.30699846},
#              {'text': 'l', 'confidence': 0.35740063},
#              {'text': 'l', 'confidence': 0.28683615},
#              {'text': 'u', 'confidence': 0.25505587},
#              {'text': 't', 'confidence': 0.26176998},
#              {'text': 'u', 'confidence': 0.24804014},
#              {'text': 'n', 'confidence': 0.27056462},
#              {'text': 't', 'confidence': 0.29011488},
#              {'text': 'i', 'confidence': 0.23759858},
#              {'text': 'l', 'confidence': 0.29864377},
#              {'text': 'l', 'confidence': 0.23794894},
#              {'text': 'a', 'confidence': 0.26708144},
#              {'text': 's', 'confidence': 0.2467691},
#              {'text': 'u', 'confidence': 0.24099705},
#              {'text': 'k', 'confidence': 0.25759375},
#              {'text': 'a', 'confidence': 0.27961788},
#              {'text': 't', 'confidence': 0.3168725},
#              {'text': 'l', 'confidence': 0.30882698},
#              {'text': 'a', 'confidence': 0.29133347},
#              {'text': 't', 'confidence': 0.23455504},
#              {'text': 'ı', 'confidence': 0.28133905},
#              {'text': 'l', 'confidence': 0.2964248},
#              {'text': 'ı', 'confidence': 0.23124556},
#              {'text': 'h', 'confidence': 0.26428825},
#              {'text': 'ı', 'confidence': 0.26575},
#              {'text': 'd', 'confidence': 0.35876623},
#              {'text': 'ı', 'confidence': 0.2782681},
#              {'text': 'b', 'confidence': 0.2907598},
#              {'text': 'ı', 'confidence': 0.25927088},
#              {'text': 'k', 'confidence': 0.26320162},
#              {'text': 'l', 'confidence': 0.32069978},
#              {'text': 'a', 'confidence': 0.3343611},
#              {'text': 'd', 'confidence': 0.36457115},
#              {'text': 'ı', 'confidence': 0.30352065},
#              {'text': 'k', 'confidence': 0.27682123},
#              {'text': 'a', 'confidence': 0.28445247},
#              {'text': 'l', 'confidence': 0.2965563},
#              {'text': 'ı', 'confidence': 0.32490522},
#              {'text': 'k', 'confidence': 0.29476517},
#              {'text': 'ı', 'confidence': 0.29155535},
#              {'text': 'l', 'confidence': 0.27777427},
#              {'text': 'ı', 'confidence': 0.31177333},
#              {'text': 'f', 'confidence': 0.33273578},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': 'l',
#               'confidence': 0.38295016}],
#             'confidence': 0.29122666}],
#           'confidence': 0.3003503}],
#         'blockType': 'TEXT',
#         'confidence': 0.3003503},
#        {'boundingBox': {'normalizedVertices': [{'x': 0.29726517,
#            'y': 0.9763407},
#           {'x': 0.69916767, 'y': 0.9763407},
#           {'x': 0.69916767, 'y': 0.99369085},
#           {'x': 0.29726517, 'y': 0.99369085}]},
#         'paragraphs': [{'boundingBox': {'normalizedVertices': [{'x': 0.29726517,
#              'y': 0.9763407},
#             {'x': 0.69916767, 'y': 0.9763407},
#             {'x': 0.69916767, 'y': 0.99369085},
#             {'x': 0.29726517, 'y': 0.99369085}]},
#           'words': [{'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.29726517,
#                'y': 0.9763407},
#               {'x': 0.34244946, 'y': 0.9763407},
#               {'x': 0.34244946, 'y': 0.99369085},
#               {'x': 0.29726517, 'y': 0.99369085}]},
#             'symbols': [{'text': 'S', 'confidence': 0.961797},
#              {'text': 'o', 'confidence': 0.97441965},
#              {'text': 'u', 'confidence': 0.9868634},
#              {'text': 'r', 'confidence': 0.9951464},
#              {'text': 'c', 'confidence': 0.99385375},
#              {'text': 'e', 'confidence': 0.9857464}],
#             'confidence': 0.9829711},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.34244946,
#                'y': 0.9763407},
#               {'x': 0.34601665, 'y': 0.9763407},
#               {'x': 0.34601665, 'y': 0.99369085},
#               {'x': 0.34244946, 'y': 0.99369085}]},
#             'symbols': [{'property': {'detectedBreak': {'type': 'SPACE'}},
#               'text': ':',
#               'confidence': 0.97677535}],
#             'confidence': 0.97677535},
#            {'property': {'detectedLanguages': [{'languageCode': 'en',
#                'confidence': 1}]},
#             'boundingBox': {'normalizedVertices': [{'x': 0.3507729,
#                'y': 0.9763407},
#               {'x': 0.69916767, 'y': 0.9763407},
#               {'x': 0.69916767, 'y': 0.99369085},
#               {'x': 0.3507729, 'y': 0.99369085}]},
#             'symbols': [{'text': 'h', 'confidence': 0.9906101},
#              {'text': 't', 'confidence': 0.9915459},
#              {'text': 't', 'confidence': 0.9937098},
#              {'text': 'p', 'confidence': 0.9950934},
#              {'text': 's', 'confidence': 0.9867646},
#              {'text': ':', 'confidence': 0.9699129},
#              {'text': '/', 'confidence': 0.9527213},
#              {'text': '/', 'confidence': 0.9741728},
#              {'text': 'w', 'confidence': 0.9907241},
#              {'text': 'w', 'confidence': 0.99276465},
#              {'text': 'w', 'confidence': 0.99234515},
#              {'text': '.', 'confidence': 0.9887041},
#              {'text': 'i', 'confidence': 0.9955746},
#              {'text': 'n', 'confidence': 0.99665254},
#              {'text': 'd', 'confidence': 0.9901751},
#              {'text': 'u', 'confidence': 0.986195},
#              {'text': 's', 'confidence': 0.98223925},
#              {'text': 't', 'confidence': 0.992183},
#              {'text': 'r', 'confidence': 0.9944381},
#              {'text': 'y', 'confidence': 0.99007636},
#              {'text': 'd', 'confidence': 0.9866993},
#              {'text': 'o', 'confidence': 0.99185085},
#              {'text': 'c', 'confidence': 0.98835593},
#              {'text': 'u', 'confidence': 0.9903709},
#              {'text': 'm', 'confidence': 0.99030966},
#              {'text': 'e', 'confidence': 0.9899328},
#              {'text': 'n', 'confidence': 0.9946691},
#              {'text': 't', 'confidence': 0.9953618},
#              {'text': 's', 'confidence': 0.99378103},
#              {'text': '.', 'confidence': 0.9905323},
#              {'text': 'u', 'confidence': 0.9869778},
#              {'text': 'c', 'confidence': 0.98596895},
#              {'text': 's', 'confidence': 0.9832077},
#              {'text': 'f', 'confidence': 0.9879423},
#              {'text': '.', 'confidence': 0.9838499},
#              {'text': 'e', 'confidence': 0.9929666},
#              {'text': 'd', 'confidence': 0.9949781},
#              {'text': 'u', 'confidence': 0.99167943},
#              {'text': '/', 'confidence': 0.9840126},
#              {'text': 'd', 'confidence': 0.9833137},
#              {'text': 'o', 'confidence': 0.9942714},
#              {'text': 'c', 'confidence': 0.9959155},
#              {'text': 's', 'confidence': 0.99320203},
#              {'text': '/', 'confidence': 0.9756206},
#              {'text': 'y', 'confidence': 0.9826542},
#              {'text': 't', 'confidence': 0.98869604},
#              {'text': 'x', 'confidence': 0.95078695},
#              {'text': 'k', 'confidence': 0.9830378},
#              {'text': '0', 'confidence': 0.9691903},
#              {'text': '0', 'confidence': 0.98278713},
#              {'text': '9', 'confidence': 0.98009765},
#              {'property': {'detectedBreak': {'type': 'LINE_BREAK'}},
#               'text': '1',
#               'confidence': 0.988237}],
#             'confidence': 0.9868819}],
#           'confidence': 0.9863129}],
#         'blockType': 'TEXT',
#         'confidence': 0.9863129}],
#       'confidence': 0.7344208}],
#     'text': '--- BETTY 1 WAKHBURN\n725 N 25TH\nBOX 306\nBILLINGS MT 59101\nATTNICA\nابال |\n1\n1999\n52279 1747\nTRISH IMMIGRATION\nR.J. Reynolds Tobacco\nCo.\nWINSTON\nSalem\nNC 27/02\nRess, lahıllutuntillasukatlatılıhıdıbıkladıkalıkılıfl\nSource: https://www.industrydocuments.ucsf.edu/docs/ytxk0091'},
#    'context': {'uri': 'gs://idl-dsi-bucket/pdf_files/ytxk0091.pdf',
#     'pageNumber': 4}}]}

# %%
# number of pages in the response
len(response['responses'])
# Out:
# 4

# %%
# parsing the json document
response["responses"][1].keys()
# Out:
# dict_keys(['fullTextAnnotation', 'context'])

# %%
page_1_text = response["responses"][0]['fullTextAnnotation']['text']
page_1_confidence = response["responses"][0]["fullTextAnnotation"]['pages'][0]['confidence']

# %%
print(page_1_text)
# Out:
# To All Jobacco Cos.
# Oct. 20/999
# I
# In my own handwriting,
# swear people
# are not taking
# responsibility for their own
# actions. No tone forced any
# ong to buy ous that to blame
# childish
# a co
# to smoke or not smoke.
# company for cree shove
# I quit alcohol 24 year
# II was a beer drinkers
# ago
# I shaved sue Lucky Lagers
# for years dost & a devance.
# think not! I also had
# jaundiect hadn't
# solid food for 2.40 3.
# Let us get realt
# tape response blaming
# Yeater
# our
# others - People or Com-
# panies.
# 52279 1744
# Source: https://www.industrydocuments.ucsf.edu/docs/ytxk0091

# %%
print(page_1_confidence)
# Out:
# 0.760178

# %%
type_ = language_v1.Document.Type.PLAIN_TEXT

language = "en"
document = {"content": page_1_text, "type_": type_, "language": language}

client = language_v1.LanguageServiceClient()

sentiment_response = client.analyze_sentiment(request = {'document': document})

# %%
print(sentiment_response.document_sentiment.score)
print(sentiment_response.document_sentiment.magnitude)
# Out:
# -0.6000000238418579
# 3.9000000953674316
